# %% [markdown]
# # 01 EDA
# PCB-AOI annotation summary and label distribution.

# %%
import pandas as pd
from pathlib import Path
metrics = Path('../reports/metrics')
annotations = pd.read_csv(metrics / 'annotations.csv')
annotations.head()

# %%
annotations['class_name'].value_counts()

# %%
annotations[['box_width','box_height','box_area_ratio']].describe()
