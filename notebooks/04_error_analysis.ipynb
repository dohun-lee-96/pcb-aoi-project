# %% [markdown]
# # 04 Error Analysis
# Inspect false positives, false negatives, and localization errors.

# %%
import json
from pathlib import Path
json.loads(Path('../reports/metrics/error_analysis_summary.json').read_text())

# %%
import pandas as pd
metrics = Path('../reports/metrics')
fp = pd.read_csv(metrics / 'false_positives.csv')
fn = pd.read_csv(metrics / 'false_negatives.csv')
fp.head(), fn.head()
