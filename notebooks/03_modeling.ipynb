# %% [markdown]
# # 03 Modeling
# Review YOLO baseline training outputs.

# %%
import json
from pathlib import Path
summary = json.loads(Path('../reports/metrics/training_summary.json').read_text())
summary

# %%
import pandas as pd
results_csv = Path(summary['run_dir']) / 'results.csv'
pd.read_csv(results_csv).tail() if results_csv.exists() else 'results.csv not found'
