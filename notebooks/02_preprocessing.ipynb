# %% [markdown]
# # 02 Preprocessing
# VOC XML to YOLO conversion checks.

# %%
from pathlib import Path
print(Path('../data/yolo/data.yaml').read_text(encoding='utf-8'))

# %%
import pandas as pd
manifest = pd.read_csv('../reports/metrics/yolo_manifest.csv')
manifest['target_split'].value_counts()
